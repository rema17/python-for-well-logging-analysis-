# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sales = pd.read_csv('C:\\Users\\essa\\Desktop\\data.csv')
# Out:
# C:\Users\essa\AppData\Local\Programs\Python\Python310-32\lib\site-packages\IPython\core\interactiveshell.py:3398: DtypeWarning: Columns (20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sales.head()
# Out:
#          Date  Day     Month  Year  Customer_Age Age_Group Customer_Gender  \
# 0  11/26/2013   26  November  2013            19     Youth           (<25)
# 1  11/26/2015   26  November  2015            19     Youth           (<25)
# 2   3/23/2014   23     March  2014            49    Adults         (35-64)
# 3   3/23/2016   23     March  2016            49    Adults         (35-64)
# 4   5/15/2014   15       May  2014            47    Adults         (35-64)
#
#   Country      State Product_Category  ... Unnamed: 18 Unnamed: 19  \
# 0       M     Canada          British  ...           8          45
# 1       M     Canada          British  ...           8          45
# 2       M  Australia              New  ...      4-Bike          23
# 3       M  Australia              New  ...      4-Bike          20
# 4       F  Australia              New  ...      4-Bike           4
#
#   Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# ...

# %%
sales = pd.read_csv(
    'C:\\Users\\essa\\Desktop\\data.csv',
    parse_dates=['Date'])
# Out:
# C:\Users\essa\AppData\Local\Programs\Python\Python310-32\lib\site-packages\IPython\core\interactiveshell.py:3398: DtypeWarning: Columns (20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age Age_Group Customer_Gender  \
# 0 2013-11-26   26  November  2013            19     Youth           (<25)
# 1 2015-11-26   26  November  2015            19     Youth           (<25)
# 2 2014-03-23   23     March  2014            49    Adults         (35-64)
# 3 2016-03-23   23     March  2016            49    Adults         (35-64)
# 4 2014-05-15   15       May  2014            47    Adults         (35-64)
#
#   Country      State Product_Category  ... Unnamed: 18 Unnamed: 19  \
# 0       M     Canada          British  ...           8          45
# 1       M     Canada          British  ...           8          45
# 2       M  Australia              New  ...      4-Bike          23
# 3       M  Australia              New  ...      4-Bike          20
# 4       F  Australia              New  ...      4-Bike           4
#
#   Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# ...

# %%
sales.shape
# Out:
# (113036, 28)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 28 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  object
#  13  Unit_Cost         113036 non-null  object
#  14  Unit_Price        113036 non-null  object
# ...

# %%
sales.describe()
# Out:
#                  Day           Year   Customer_Age   Unnamed: 22  \
# count  113036.000000  113036.000000  113036.000000  59830.000000
# mean       15.665753    2014.401739      35.919212    143.592796
# std         8.781567       1.272510      11.021936    479.813955
# min         1.000000    2011.000000      17.000000      1.000000
# 25%         8.000000    2013.000000      28.000000      7.000000
# 50%        16.000000    2014.000000      35.000000     29.000000
# 75%        23.000000    2016.000000      43.000000    101.750000
# max        31.000000    2016.000000      87.000000  12451.000000
#
#         Unnamed: 23   Unnamed: 24   Unnamed: 25  Unnamed: 26  Unnamed: 27
# count  47620.000000  23772.000000  11560.000000  4000.000000   600.000000
# mean     109.511697    115.310912     83.024048    72.123000    69.581667
# std      186.453904    218.704747    158.865626    95.122076    38.324988
# min        1.000000      1.000000      2.000000     2.000000     4.000000
# ...

# %%
sales['Unit_Cost'].describe()
# Out:
# count     113036
# unique       175
# top          and
# freq       27162
# Name: Unit_Cost, dtype: object

# %%
sales['Year'].mean()
# Out:
# 2014.4017392689054

# %%
sales['Year'].median()
# Out:
# 2014.0

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
sales['Profit'].plot(kind='density', figsize=(14,6)) # kde
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 sales['Profit'].plot(kind='density', figsize=(14,6))
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
ax = sales['Year'].plot(kind='density', figsize=(14,6)) # kde
ax.axvline(sales['Year'].mean(), color='red')
ax.axvline(sales['Year'].median(), color='green')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 ax = sales['Year'].plot(kind='density', figsize=(14,6)) # kde
#       2 ax.axvline(sales['Year'].mean(), color='red')
#       3 ax.axvline(sales['Year'].median(), color='green')
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
# ...

# %%
ax = sales['Year'].plot(kind='hist', figsize=(14,6))
ax.set_ylabel('Number of Sales')
ax.set_xlabel('dollars')
# Out:
# Text(0.5, 0, 'dollars')

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age Age_Group Customer_Gender  \
# 0 2013-11-26   26  November  2013            19     Youth           (<25)
# 1 2015-11-26   26  November  2015            19     Youth           (<25)
# 2 2014-03-23   23     March  2014            49    Adults         (35-64)
# 3 2016-03-23   23     March  2016            49    Adults         (35-64)
# 4 2014-05-15   15       May  2014            47    Adults         (35-64)
#
#   Country      State Product_Category  ... Unnamed: 18 Unnamed: 19  \
# 0       M     Canada          British  ...           8          45
# 1       M     Canada          British  ...           8          45
# 2       M  Australia              New  ...      4-Bike          23
# 3       M  Australia              New  ...      4-Bike          20
# 4       F  Australia              New  ...      4-Bike           4
#
#   Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# ...

# %%
sales['Age_Group'].value_counts()
# Out:
# Adults     55824
# Young      38654
# Youth      17828
# Seniors      730
# Name: Age_Group, dtype: int64

# %%
sales['Age_Group'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='Age_Group'>

# %%
ax = sales['Age_Group'].value_counts().plot(kind='bar', figsize=(14,6))
ax.set_ylabel('Number of Sales')
# Out:
# Text(0, 0.5, 'Number of Sales')

# %%
corr = sales.corr()

corr
# Out:
#                    Day      Year  Customer_Age  Unnamed: 22  Unnamed: 23  \
# Day           1.000000 -0.007635     -0.014296     0.007229     0.011442
# Year         -0.007635  1.000000      0.040994    -0.124590    -0.014345
# Customer_Age -0.014296  0.040994      1.000000    -0.049087     0.088034
# Unnamed: 22   0.007229 -0.124590     -0.049087     1.000000     0.770880
# Unnamed: 23   0.011442 -0.014345      0.088034     0.770880     1.000000
# Unnamed: 24   0.005474 -0.017431      0.006736     0.976330     0.880474
# Unnamed: 25   0.006186 -0.026962     -0.018681     0.753174     0.986997
# Unnamed: 26   0.004908 -0.030216     -0.012138     0.145062     0.741554
# Unnamed: 27  -0.007386 -0.027457      0.038033     0.997560          NaN
#
#               Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27
# Day              0.005474     0.006186     0.004908    -0.007386
# Year            -0.017431    -0.026962    -0.030216    -0.027457
# ...

# %%
fig = plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %%
sales.plot(kind='scatter', x='Customer_Age', y='Revenue', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Revenue'>

# %%
sales.plot(kind='scatter', x='Revenue', y='Profit', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Revenue', ylabel='Profit'>

# %%
ax = sales[['Age_Group', 'Year']].boxplot(by='Age_Group', figsize=(10,6))
ax.set_ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
boxplot_cols = ['Year', 'Customer_Age', 'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit']

sales[boxplot_cols].plot(kind='box', subplots=True, layout=(2,3), figsize=(14,8))
# Out:
# Year               AxesSubplot(0.125,0.53;0.227941x0.35)
# Customer_Age    AxesSubplot(0.398529,0.53;0.227941x0.35)
# dtype: object

# %%
sales['Revenue_per_Age'] = sales['Revenue'] / sales['Customer_Age']

sales['Revenue_per_Age'].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\core\ops\array_ops.py:166, in _na_arithmetic_op(left, right, op, is_cmp)
#     165 try:
# --> 166     result = func(left, right)
#     167 except TypeError:
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\core\computation\expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      68     _store_test_result(False)
# ---> 69 return op(a, b)
#
# ...

# %%
sales['Revenue_per_Age'].plot(kind='hist', figsize=(14,6))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Revenue_per_Age'
#
# ...

# %%
sales['Calculated_Cost'] = sales['Order_Quantity'] * sales['Unit_Cost']

sales['Calculated_Cost'].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\core\ops\array_ops.py:166, in _na_arithmetic_op(left, right, op, is_cmp)
#     165 try:
# --> 166     result = func(left, right)
#     167 except TypeError:
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\core\computation\expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      68     _store_test_result(False)
# ---> 69 return op(a, b)
#
# ...

# %%
# !pip install lxml
