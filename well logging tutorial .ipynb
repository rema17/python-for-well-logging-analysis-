# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#read excel file:by using file location.
well = pd.read_csv('C:\\Users\\Well292.csv', header=0)

print(well)
# Out:
#        DEPTH     GR      SP    RHOB   DT    NPHI   MSFL    ILD  CALIPER
# 0     8200.0        53    3    2.21  114    0.45    0.6    0.6     12.1
# 1     8200.5        54    4    2.22  114    0.44    0.7    0.5     12.1
# 2     8201.0        54    5    2.21  115    0.42    0.7    0.5     12.1
# 3     8201.5        54    5    2.21  115    0.41    0.6    0.5     12.0
# 4     8202.0        53    5    2.21  114    0.41    0.7    0.5     12.0
# ...      ...       ...  ...     ...  ...     ...    ...    ...      ...
# 2216  9308.0      -999  999 -999.00 -999 -999.00 -999.0 -999.0   -999.0
# 2217  9308.5      -999  999 -999.00 -999 -999.00 -999.0 -999.0   -999.0
# 2218  9309.0      -999  999 -999.00 -999 -999.00 -999.0 -999.0   -999.0
# 2219  9309.5      -999  999 -999.00 -999 -999.00 -999.0 -999.0   -999.0
# 2220  9310.0      -999  999 -999.00 -999 -999.00 -999.0 -999.0   -999.0
#
# [2221 rows x 9 columns]

# %%
well.head()
# Out:
#     DEPTH     GR     SP  RHOB   DT  NPHI  MSFL  ILD  CALIPER
# 0  8200.0        53   3  2.21  114  0.45   0.6  0.6     12.1
# 1  8200.5        54   4  2.22  114  0.44   0.7  0.5     12.1
# 2  8201.0        54   5  2.21  115  0.42   0.7  0.5     12.1
# 3  8201.5        54   5  2.21  115  0.41   0.6  0.5     12.0
# 4  8202.0        53   5  2.21  114  0.41   0.7  0.5     12.0

# %%
#We can also view some statistics on the curves by using the describe() function.
well.describe()
# Out:
#              DEPTH        GR              SP         RHOB           DT  \
# count  2221.000000  2221.000000  2221.000000  2221.000000  2221.000000
# mean   8755.000000    32.349392   -43.983341    -3.099995    75.487618
# std     320.645898    78.478553    85.964607    73.418885    84.502463
# min    8200.000000  -999.000000   -97.000000  -999.000000  -999.000000
# 25%    8477.500000    20.000000   -81.000000     2.210000    69.000000
# 50%    8755.000000    35.000000   -53.000000     2.340000    74.000000
# 75%    9032.500000    53.000000   -20.000000     2.440000    91.000000
# max    9310.000000   102.000000   999.000000     2.790000   132.000000
#
#               NPHI         MSFL          ILD      CALIPER
# count  2221.000000  2221.000000  2221.000000  2221.000000
# mean     -5.134232     3.427195     0.257767     4.101666
# std      73.268792    74.893280    91.579406    73.984062
# min    -999.000000  -999.000000  -999.000000  -999.000000
# ...

# %%
well.replace(-999, np.NaN, inplace=True)

# %%
well.describe()
# Out:
#              DEPTH        GR              SP         RHOB           DT  \
# count  2221.000000  2209.000000  2221.000000  2209.000000  2208.000000
# mean   8755.000000    37.952014   -43.983341     2.310054    81.813859
# std     320.645898    19.495481    85.964607     0.193038    18.497045
# min    8200.000000     1.000000   -97.000000     1.320000    57.000000
# 25%    8477.500000    21.000000   -81.000000     2.210000    69.000000
# 50%    8755.000000    36.000000   -53.000000     2.340000    74.000000
# 75%    9032.500000    53.000000   -20.000000     2.440000    91.000000
# max    9310.000000   102.000000   999.000000     2.790000   132.000000
#
#               NPHI         MSFL          ILD      CALIPER
# count  2209.000000  2209.000000  2209.000000  2209.000000
# mean      0.264767     8.872703     5.686057     9.550837
# std       0.135731    12.191103    54.554289     2.265806
# min       0.070000     0.200000     0.200000     7.300000
# ...

# %%
well.head()
# Out:
#     DEPTH     GR     SP  RHOB     DT  NPHI  MSFL  ILD  CALIPER
# 0  8200.0      53.0   3  2.21  114.0  0.45   0.6  0.6     12.1
# 1  8200.5      54.0   4  2.22  114.0  0.44   0.7  0.5     12.1
# 2  8201.0      54.0   5  2.21  115.0  0.42   0.7  0.5     12.1
# 3  8201.5      54.0   5  2.21  115.0  0.41   0.6  0.5     12.0
# 4  8202.0      53.0   5  2.21  114.0  0.41   0.7  0.5     12.0

# %%
well.replace(-999, np.NaN, inplace=True)

# %%
well.head(20)
# Out:
#      DEPTH     GR     SP  RHOB     DT  NPHI  MSFL  ILD  CALIPER
# 0   8200.0      53.0   3  2.21  114.0  0.45   0.6  0.6     12.1
# 1   8200.5      54.0   4  2.22  114.0  0.44   0.7  0.5     12.1
# 2   8201.0      54.0   5  2.21  115.0  0.42   0.7  0.5     12.1
# 3   8201.5      54.0   5  2.21  115.0  0.41   0.6  0.5     12.0
# 4   8202.0      53.0   5  2.21  114.0  0.41   0.7  0.5     12.0
# 5   8202.5      53.0   5  2.21  114.0  0.42   0.7  0.5     12.0
# 6   8203.0      54.0   5  2.21  113.0  0.42   0.7  0.5     12.0
# 7   8203.5      54.0   5  2.22  114.0  0.43   0.7  0.5     11.9
# 8   8204.0      55.0   5  2.23  113.0  0.44   0.7  0.5     11.9
# 9   8204.5      55.0   6  2.24  113.0  0.45   0.7  0.5     11.8
# 10  8205.0      54.0   6  2.24  114.0  0.45   0.8  0.5     11.6
# 11  8205.5      55.0   6  2.23  113.0  0.44   0.8  0.5     11.4
# 12  8206.0      58.0   6  2.23  111.0  0.43   0.7  0.5     11.2
# 13  8206.5      61.0   6  2.24  110.0  0.40   0.8  0.6     11.0
# ...

# %%
ax = well['DEPTH'].plot(kind='density', figsize=(14,6)) # kde
ax.axvline(sales['DEPTH'].mean(), color='red')
ax.axvline(sales['GR'].median(), color='green')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 ax = well['DEPTH'].plot(kind='density', figsize=(14,6)) # kde
#       2 ax.axvline(sales['DEPTH'].mean(), color='red')
#       3 ax.axvline(sales['GR'].median(), color='green')
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
# ...

# %%
well.plot(kind = 'scatter', x = 'NPHI', y = 'RHOB', ylim=(3, 2))
# Out:
# <AxesSubplot:xlabel='NPHI', ylabel='RHOB'>

# %%
well.plot(kind = 'scatter', x = 'NPHI', y = 'RHOB', c='GR', 
          colormap='jet', 
          ylim=(3, 2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\matplotlib\axes\_axes.py:4220, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4219 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4220     colors = mcolors.to_rgba_array(c)
#    4221 except (TypeError, ValueError) as err:
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\matplotlib\colors.py:359, in to_rgba_array(c, alpha)
#     358 if isinstance(c, str):
# --> 359     raise ValueError("Using a string of single character colors as "
#     360                      "a color sequence is not supported. The colors can "
#     361                      "be passed as an explicit list instead.")
#     363 if len(c) == 0:
#
# ...

# %%
well['GR'].plot(kind="hist", bins = 30)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GR'
#
# ...

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
! jt -r
# Out:
# Reset css and font defaults in:
# C:\Users\essa\.jupyter\custom &
# C:\Users\essa\AppData\Roaming\jupyter\nbextensions

# %%
# !pip install striplog

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 import striplog
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\striplog\__init__.py:11, in <module>
#       9 from .position import Position
#      10 from .interval import Interval
# ---> 11 from .striplog import Striplog
#      12 from .markov import Markov_chain
#      13 from .logo import plot
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\striplog\striplog.py:27, in <module>
#      25 from .legend import Legend
#      26 from .canstrat import parse_canstrat
# ---> 27 from .markov import Markov_chain
#      28 from .lexicon import Lexicon
#      29 from . import utils
#
# File ~\AppData\Local\Programs\Python\Python310-32\lib\site-packages\striplog\markov.py:7, in <module>
#       4 from collections import namedtuple
# ...
